# %% [markdown]
# This Notebook contains all code related to Data Cleaning and Merges. Enjoy!

# %%
import pandas as pd

# %%
# !pip install gapminder
from gapminder import gapminder as df_gapminder

# %%
df_gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
data_dir = "https://raw.githubusercontent.com/bellamccarty/data/main/"
df_goalscorers = pd.read_csv(data_dir + "goalscorers.csv")
df_shootouts = pd.read_csv(data_dir + "shootouts.csv")
df_results = pd.read_csv(data_dir + "results.csv")

# %%
df_goalscorers["country"] = df_goalscorers["team"]

# %%
df_shootouts["country"] = df_goalscorers['home_team']

# %%
df_results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
data_frames = [df_goalscorers, df_shootouts, df_results]
for df in data_frames:
  df['year'] = pd.DatetimeIndex(df['date']).year

# %%
df_goalscorers = df_goalscorers.merge(df_gapminder, on = ["country", "year"])
df_shootouts = df_shootouts.merge(df_gapminder, on = ["country", "year"])
df_results = df_results.merge(df_gapminder, on = ["country", "year"])

# %%
df_goalscorers.head()
# Out:
#          date  home_team         away_team        team                 scorer  \
# 0  1957-01-16   Portugal  Northern Ireland    Portugal         Manuel Vasques
# 1  1957-05-26   Portugal             Italy    Portugal         Manuel Vasques
# 2  1957-05-26   Portugal             Italy    Portugal  António Dias Teixeira
# 3  1957-05-26   Portugal             Italy    Portugal                Matateu
# 4  1957-02-10  Guatemala        Costa Rica  Costa Rica            Jorge Monge
#
#    minute  own_goal  penalty  year     country continent  lifeExp      pop  \
# 0    24.0     False    False  1957    Portugal    Europe   61.510  8817650
# 1    41.0     False    False  1957    Portugal    Europe   61.510  8817650
# 2    81.0     False    False  1957    Portugal    Europe   61.510  8817650
# 3    87.0     False    False  1957    Portugal    Europe   61.510  8817650
# 4    11.0     False    False  1957  Costa Rica  Americas   60.026  1112300
#
#      gdpPercap
# 0  3774.571743
# ...

# %%
df_shootouts.head()
# Out:
#          date    home_team    away_team       winner  year    country  \
# 0  1967-08-22        India       Taiwan       Taiwan  1967      Chile
# 1  1972-05-07  South Korea         Iraq         Iraq  1972      Chile
# 2  1972-05-17     Thailand  South Korea  South Korea  1972      Chile
# 3  1972-05-19     Thailand     Cambodia     Thailand  1972  Argentina
# 4  1977-01-09      Tunisia      Morocco      Tunisia  1977  Argentina
#
#   continent  lifeExp       pop     gdpPercap
# 0  Americas   60.523   8858908   5106.654313
# 1  Americas   63.441   9717524   5494.024437
# 2  Americas   63.441   9717524   5494.024437
# 3  Americas   67.065  24779799   9443.038526
# 4  Americas   68.481  26983828  10079.026740

# %%
df_results.head()
# Out:
#          date home_team    away_team  home_score  away_score  \
# 0  1952-02-24   Belgium        Italy           2           0
# 1  1952-04-06   Belgium  Netherlands           4           2
# 2  1952-05-22   Belgium       France           1           2
# 3  1952-10-19   Belgium  Netherlands           2           1
# 4  1952-03-16     Chile       Panama           6           1
#
#                   tournament      city  country  neutral  year continent  \
# 0                   Friendly  Brussels  Belgium    False  1952    Europe
# 1                   Friendly   Antwerp  Belgium    False  1952    Europe
# 2                   Friendly  Brussels  Belgium    False  1952    Europe
# 3                   Friendly   Antwerp  Belgium    False  1952    Europe
# 4  Pan American Championship  Santiago    Chile    False  1952  Americas
#
#    lifeExp      pop    gdpPercap
# 0   68.000  8730405  8343.105127
# 1   68.000  8730405  8343.105127
# 2   68.000  8730405  8343.105127
# ...
